# %% [markdown]
# <a href="https://colab.research.google.com/github/HarishRock0/DSGP/blob/master/service/dayone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sympy as sp
import cv2
from scipy.fftpack import dct
from IPython.display import display, Math

# %%
x , y = sp.symbols('x y')

# %%
fx = (x**3) + (5 * (x**2)) - (7*x) + 10
diff = sp.diff(fx, x)
display(Math(f'f\'(x) = {diff}'))
# Out:
# $\displaystyle f'(x) = 3*x**2 + 10*x - 7$

# %%
fx = sp.sqrt(x) + (1/x)
diff = sp.diff(fx,x)
print (diff)
# Out:
# -1/x**2 + 1/(2*sqrt(x))

# %%
fx = sp.exp(x) + sp.log(x)
diff = sp.diff(fx,x)
print (diff)
# Out:
# exp(x) + 1/x

# %%
fx = sp.sin(x) + sp.cos(x)
diff = sp.diff(fx,x)
print (diff)
# Out:
# -sin(x) + cos(x)

# %%
fx = (x**2)*sp.sin(x)
diff = sp.diff(fx,x)
print (diff)
# Out:
# x**2*cos(x) + 2*x*sin(x)

# %%
fx = ((2*(x**2))+1)/(x+3)
diff = sp.diff(fx,x)
print(diff)
# Out:
# 4*x/(x + 3) - (2*x**2 + 1)/(x + 3)**2

# %%
fx = ((4*(x**2)) - x - 2)**3
diff = sp.diff(fx,x)
diff
# Out:
# (24*x - 3)*(4*x**2 - x - 2)**2

# %%
fx = (sp.log((x**2) + 1))
diff = sp.diff(fx)
diff
# Out:
# 2*x/(x**2 + 1)

# %%
fx = (sp.exp(x)**(3*x))*(sp.sin(2*x))
diff = sp.diff(fx,x)
diff
# Out:
# (3*x + 3*log(exp(x)))*exp(x)**(3*x)*sin(2*x) + 2*exp(x)**(3*x)*cos(2*x)

# %%
import sympy as sp

x, y = sp.symbols('x y')
f = x**2 * y + 3 * y**2  # Displays: x**2*y + 3*y**2

# Partial derivatives
f_x = sp.diff(f, x)
f_y = sp.diff(f, y)

f_x # 2*x*y
f_y # x**2 + 6*y
# Out:
# x**2 + 6*y

# %%
fx = x**2 + 3*x
diff = sp.diff(fx,x)
diff

point = [0,1,2,3]

for val in point:
  print(diff.subs(x,val))
# Out:
# 3
# 5
# 7
# 9

# %%
fx = sp.sin(x)
diff = sp.diff(fx,x)
diff

range = 0 , 2*np.pi

for val in range:
  print(diff.subs(x,val))
# Out:
# 1
# 1.00000000000000

# %%
fx = x*sp.sin(x)
inte = sp.integrate(fx)
inte
# Out:
# -x*cos(x) + sin(x)

# %%
fx = (x**3) + (5 * (y**3)) - (7*x) + 10
diff_x = sp.diff(fx, x)
diff_x
# Out:
# 3*x**2 - 7

# %%
diff_y = sp.diff(fx,y)
diff_y
# Out:
# 15*y**2

# %%
difftwo = sp.diff(diff_x,x)
difftwo
# Out:
# 6*x

# %%
diffthree = sp.diff(diff_y,y)
diffthree
# Out:
# 30*y

# %%
let_x = [1,2,3,4,5,6,7,8]
let_y = [2,4,6,8,10,12,14,16]

for val in let_x:
  disx = diff_x.subs(x,val)
  print(disx)
# Out:
# -4
# 5
# 20
# 41
# 68
# 101
# 140
# 185

# %%
for val in let_y:
  disy =diff_y.subs(y,val)
  print(disy)
# Out:
# 60
# 240
# 540
# 960
# 1500
# 2160
# 2940
# 3840

# %%
plt.plot(disx,disy)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph')
plt.show()

# %%
fx = sp.cos()
